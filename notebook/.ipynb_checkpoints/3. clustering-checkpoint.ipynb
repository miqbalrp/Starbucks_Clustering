# %% [markdown]
# # Clustering with K-Means

# %% [markdown]
# With the data from EDA process before, we will choose some features to be trained for creating clusters using K-Means.

# %% [markdown]
# ## 0. Import Library and Data

# %%
fig_dir = r'..\result\final-clustering\\'
export_figure = True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
data_dir = r'..\data\cleansed\\'
file_name = 'data_eda.csv'
df = pd.read_csv(data_dir+file_name)
df.sample(5)
# Out:
#                                  person gender  age became_member_on  \
# 8320   97893bd25b3140cda0b3a45c22e0ac2a      F   26       2017-01-27
# 7912   900e1382081b49b6ac7512fc02775d0f      F   49       2016-07-04
# 984    12583497d042470499110e831f8f3d0c      M   42       2018-06-07
# 10619  c0b78b7b2a1e49e8b6d6c0eb076d8706      F   61       2018-03-28
# 7549   89db9e6efae9458cb649a6474671d039      M   36       2015-12-25
#
#        bmo_year   income  amount_sum  amount_mean  offer received  \
# 8320       2017  52000.0       49.87     4.155833             4.0
# 7912       2016  80000.0      152.24    19.030000             5.0
# 984        2018  44000.0      138.64    15.404444             4.0
# 10619      2018  40000.0        5.67     1.890000             2.0
# 7549       2015  50000.0      162.28    10.818667             5.0
#
#        offer viewed  offer completed age_group  income_group   bogo  \
# 8320            2.0              2.0     Youth  Lower-Middle  100.0
# ...

# %% [markdown]
# ## 1. Show and Choose Right Features

# %% [markdown]
# Before we get started, we will first try to see at a glance how the condition of our data is currently.

# %%
fig_title = 'Final Distribution Before Clustering'

fig, axs = plt.subplots(4,3, figsize=(16,16))
fig.suptitle(fig_title, fontsize=20)

sns.countplot(ax=axs[0,0], data=df, x='gender', edgecolor='k')
sns.histplot(ax=axs[0,1], data=df, x='age', edgecolor='k')
sns.countplot(ax=axs[0,2], data=df, x='bmo_year', edgecolor='k')
sns.histplot(ax=axs[1,0], data=df, x='income', edgecolor='k')
sns.histplot(ax=axs[1,1], data=df, x='amount_sum', edgecolor='k')
sns.histplot(ax=axs[1,2], data=df, x='amount_mean', edgecolor='k')
sns.countplot(ax=axs[2,0], data=df, x='offer received', edgecolor='k')
sns.countplot(ax=axs[2,1], data=df, x='offer viewed', edgecolor='k')
sns.countplot(ax=axs[2,2], data=df, x='offer completed', edgecolor='k')
sns.countplot(ax=axs[3,0], data=df, x='chance bogo', edgecolor='k')
sns.countplot(ax=axs[3,1], data=df, x='chance discount', edgecolor='k')
sns.countplot(ax=axs[3,2], data=df, x='chance informational', edgecolor='k', order=['Low', 'High'])

axs[0,0].set_ylabel('')
axs[0,1].set_ylabel('')
axs[0,2].set_ylabel('')
axs[1,0].set_ylabel('')
axs[1,1].set_ylabel('')
axs[1,2].set_ylabel('')
axs[2,0].set_ylabel('')
axs[2,1].set_ylabel('')
axs[2,2].set_ylabel('')
axs[3,0].set_ylabel('')
axs[3,1].set_ylabel('')
axs[3,2].set_ylabel('')

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
plt.show()

# %% [markdown]
# Since K-Means work better for numerical features, we will only use these columns for clustering purpose:
# * income
# * amount_sum
# * amount_mean
# * chance bogo (in numeric)
# * chance discount (in numeric)
# * chance informational (in numeric)

# %%
features = df[['income','amount_sum','amount_mean', 
               'bogo', 'discount', 'informational',
              ]]
features = features.fillna(0)

features.describe()
# Out:
#               income    amount_sum   amount_mean          bogo      discount  \
# count   14002.000000  14002.000000  14002.000000  14002.000000  14002.000000
# mean    65033.780888    107.035041     13.630012     40.207470     41.301243
# std     21613.801585     89.345178      9.014319     38.706903     37.963647
# min     30000.000000      0.150000      0.150000      0.000000      0.000000
# 25%     48000.000000     33.282500      3.809063      0.000000      0.000000
# 50%     63000.000000     87.340000     14.005000     50.000000     50.000000
# 75%     79000.000000    157.807500     21.100500     66.666667     66.666667
# max    120000.000000    953.390000     39.646667    100.000000    100.000000
#
#        informational
# count   14002.000000
# mean       57.557135
# std        35.406283
# min         0.000000
# 25%        50.000000
# 50%        50.000000
# 75%       100.000000
# max       100.000000

# %% [markdown]
# ## 1. Scaling Numerical Features

# %% [markdown]
# ### 1.a. Box-Cox Transformation

# %%
bc = PowerTransformer(method='box-cox', standardize=True)

def box_cox(feature):
    array = np.array(feature)
    array_reshape = array.reshape((len(array),1))
    feature_scaled = bc.fit_transform(array_reshape)
    return feature_scaled

fig_title = 'Before and After Box-Cox Tranformation'

fig, axs = plt.subplots(2,3, figsize=(15,10))
fig.suptitle(fig_title, fontsize=20)

sns.histplot(ax=axs[0,0], data=features['income'])
sns.histplot(ax=axs[0,1], data=features['amount_sum'])
sns.histplot(ax=axs[0,2], data=features['amount_mean'])

sns.histplot(ax=axs[1,0], x=box_cox(features['income'])[:,0], color='r')
sns.histplot(ax=axs[1,1], x=box_cox(features['amount_sum'])[:,0], color='r')
sns.histplot(ax=axs[1,2], x=box_cox(features['amount_mean'])[:,0], color='r')

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
    
plt.show()

# %% [markdown]
# ### 1.b. Quantile Transformation

# %%
qt = QuantileTransformer(n_quantiles=1000, output_distribution='normal',
                         random_state=69)

def quantile(feature):
    array = np.array(feature)
    array_reshape = array.reshape((len(array),1))
    feature_scaled = qt.fit_transform(array_reshape)
    return feature_scaled

fig_title = 'Before and After Quantile Tranformation'

fig, axs = plt.subplots(2,3, figsize=(15,10))
fig.suptitle(fig_title, fontsize=20)

sns.histplot(ax=axs[0,0], data=features['income'])
sns.histplot(ax=axs[0,1], data=features['amount_sum'])
sns.histplot(ax=axs[0,2], data=features['amount_mean'])

sns.histplot(ax=axs[1,0], x=quantile(features['income'])[:,0], color='r')
sns.histplot(ax=axs[1,1], x=quantile(features['amount_sum'])[:,0], color='r')
sns.histplot(ax=axs[1,2], x=quantile(features['amount_mean'])[:,0], color='r')

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
    
plt.show()

# %% [markdown]
# ### 1.c. Min-Max Tranformation

# %%
#mm = StandardScaler()
mm = MinMaxScaler()

def min_max(feature):
    array = np.array(feature)
    array_reshape = array.reshape((len(array),1))
    feature_scaled = mm.fit_transform(array_reshape)
    return feature_scaled

fig_title = 'Before and After Min-Max Tranformation'

fig, axs = plt.subplots(2,3, figsize=(15,10))
fig.suptitle(fig_title, fontsize=20)

sns.histplot(ax=axs[0,0], data=features['bogo'])
sns.histplot(ax=axs[0,1], data=features['discount'])
sns.histplot(ax=axs[0,2], data=features['informational'])

sns.histplot(ax=axs[1,0], x=min_max(features['bogo'])[:,0], color='r')
sns.histplot(ax=axs[1,1], x=min_max(features['discount'])[:,0], color='r')
sns.histplot(ax=axs[1,2], x=min_max(features['informational'])[:,0], color='r')

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
    
plt.show()

# %% [markdown]
# ### 1.d. Get Scaled Features

# %%
scaled_features = pd.DataFrame()
scaled_features['income'] = box_cox(features['income'])[:,0]
scaled_features['amount_sum'] = box_cox(features['amount_sum'])[:,0]
scaled_features['amount_mean'] = quantile(features['amount_mean'])[:,0]

scaled_features['bogo'] = min_max(features['bogo'])[:,0]
scaled_features['discount'] = min_max(features['discount'])[:,0]
scaled_features['informational'] = min_max(features['informational'])[:,0]

sns.pairplot(scaled_features)
plt.show()

# %% [markdown]
# ## 2. Determine The Best Number of Cluster

# %% [markdown]
# ### 2.a. Elbow Method
#
# From [Real Python](https://realpython.com/k-means-clustering-python/#choosing-the-appropriate-number-of-clusters):
#
# "The SSE is defined as the sum of the squared Euclidean distances of each point to its closest centroid. Since this is a measure of error, the objective of k-means is to try to minimize this value."

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init" : 10,
    "max_iter" : 300,
    "random_state" : 69,
}

sse = []
clusters_sse = range(1,11)

for k in clusters_sse:
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    sse.append(kmeans.inertia_)

# %% [markdown]
# ### 2.b. Silhouette Method
#
# From [Real Python](https://realpython.com/k-means-clustering-python/#choosing-the-appropriate-number-of-clusters):
#
# "The silhouette coefficient is a measure of cluster cohesion and separation. It quantifies how well a data point fits into its assigned cluster based on two factors:
#
# 1. How close the data point is to other points in the cluster
# 2. How far away the data point is from points in other clusters
#
# Silhouette coefficient values range between -1 and 1. Larger numbers indicate that samples are closer to their clusters than they are to other clusters."

# %%
silhouette = []
clusters_silhouette = range(2,11)

for k in clusters_silhouette:
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    silhouette.append(score)

# %%
fig_title = 'Elbow and Silhoute Method'

fig, axs = plt.subplots(2,1, figsize=(10,10), sharex=True)
fig.suptitle(fig_title, fontsize=20)

sns.lineplot(ax=axs[0],x=clusters_sse, y=sse)
sns.scatterplot(ax=axs[0],x=clusters_sse, y=sse, s=200, color='b', edgecolor='k')

sns.lineplot(ax=axs[1],x=clusters_silhouette, y=silhouette, color='r')
sns.scatterplot(ax=axs[1],x=clusters_silhouette, y=silhouette, s=200, color='r', edgecolor='k')

axs[0].set_ylabel('Inertia (SSE)')
axs[1].set_ylabel('Silhouette Score')
axs[1].set_xlabel('k', fontsize=20)

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
plt.show()

# %% [markdown]
# From SSE chart we can observe that value starts to be smooth (*arm* side) at either k=3 or k=4. <br>
# To get more confidence, we will use Silhouette Score where the value for k=3 is greater than k=4.<br>
# Therefore we will choose **k=3** as the number of clusters.

# %% [markdown]
# ## 3. Perform Clustering

# %%
kmeans = KMeans(init='random',
               n_clusters=3,
               n_init=10,
               max_iter=300,
               random_state=69)
kmeans.fit(scaled_features)

print('The KMeans need {0:.1f} iterations' .format(kmeans.n_iter_))
# Out:
# The KMeans need 13.0 iterations

# %%
cluster_name = []
for i in range(len(kmeans.labels_)):
    clusters = "Cluster " + str(kmeans.labels_[i])
    cluster_name.append(clusters)
    
df['Cluster'] = cluster_name

cluster = np.unique(df['Cluster'])

# %%
fig_title = 'Number of Clusters'

fig, axs = plt.subplots(1,1, figsize=(10,6))
fig.suptitle(fig_title, fontsize=20)

sns.countplot(data=df, x='Cluster', edgecolor='k', order=cluster)

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
plt.show()

# %% [markdown]
# From the results of clustering with k = 3, we get the number of customers who are evenly distributed ~5000 people per cluster.

# %%
data_dir = r'..\data\cleansed\\'
file_name = 'data_clusters.csv'

#df.to_csv(data_dir+file_name, index=False, header=True)

# %% [markdown]
# ## 4. Explore Clusters

# %%
df.describe()
# Out:
#                 age      bmo_year         income    amount_sum   amount_mean  \
# count  14002.000000  14002.000000   14002.000000  14002.000000  14002.000000
# mean      54.240894   2016.600843   65033.780888    107.035041     13.630012
# std       17.464301      1.203467   21613.801585     89.345178      9.014319
# min       18.000000   2013.000000   30000.000000      0.150000      0.150000
# 25%       42.000000   2016.000000   48000.000000     33.282500      3.809063
# 50%       55.000000   2017.000000   63000.000000     87.340000     14.005000
# 75%       66.000000   2017.000000   79000.000000    157.807500     21.100500
# max      101.000000   2018.000000  120000.000000    953.390000     39.646667
#
#        offer received  offer viewed  offer completed          bogo  \
# count    14002.000000  14002.000000     14002.000000  14002.000000
# mean         4.488859      3.352164         2.216112     40.207470
# std          1.069032      1.280481         1.562224     38.706903
# ...

# %%
fig_title = 'Age and Gender Distribution of Each Cluster'

fig, axs = plt.subplots(1,1, figsize=(12,7))
fig.suptitle(fig_title, fontsize=20)

sns.boxplot(data=df, x='Cluster', y='age', hue='gender', order=cluster)
plt.legend(loc=1)

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
plt.show()

# %%
fig_title = 'Year Become Member by Clusters'

fig, axs = plt.subplots(1,1, figsize=(16,5), sharey=True)
fig.suptitle(fig_title, fontsize=20)

sns.countplot(data=df, hue='bmo_year', x='Cluster', order=cluster)

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
plt.show()

# %%
fig_title = 'Income and Total Amount of Transaction'

fig, axs = plt.subplots(1,len(cluster), figsize=(16,5), sharey=True)
fig.suptitle(fig_title, fontsize=20)

color = ['#5975A4', '#CC8963', '#5F9E6E', '#A75A5D']

for i in range(len(cluster)):
    sns.scatterplot(ax=axs[i],data=df, x='income', y='amount_sum', color='#C8C8C8')
    sns.scatterplot(ax=axs[i],data=df[df['Cluster']==cluster[i]], x='income', y='amount_sum', color=color[i])
    
if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
plt.show()

# %%
fig_title = 'Income and Average Amount of Transaction'

fig, axs = plt.subplots(1,len(cluster), figsize=(16,5), sharey=True)
fig.suptitle(fig_title, fontsize=20)

for i in range(len(cluster)):
    sns.scatterplot(ax=axs[i],data=df, x='income', y='amount_mean', color='#C8C8C8')
    sns.scatterplot(ax=axs[i],data=df[df['Cluster']==cluster[i]], x='income', y='amount_mean', color=color[i])

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')   
plt.show()

# %%
fig_title = 'Completion Chance of Offer by Each Cluster'

fig, axs = plt.subplots(1,3, figsize=(16,5))
fig.suptitle(fig_title, fontsize=20)

sns.violinplot(ax=axs[0],data=df, x='Cluster', y='bogo', order=cluster)
sns.violinplot(ax=axs[1],data=df, x='Cluster', y='discount', order=cluster)
sns.violinplot(ax=axs[2],data=df, x='Cluster', y='informational', order=cluster)

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
plt.show()

# %%
df_avg = df.groupby(['Cluster']).mean()[['bogo','discount', 'informational']]
df_avg = df_avg.reset_index(inplace=False)
df_avg = df_avg.melt(id_vars='Cluster', var_name='Offer Type', value_name='Avg Chance')

fig_title = 'Completion Chance of Offer by Each Cluster'

fig, axs = plt.subplots(1,1, figsize=(10,6))
fig.suptitle(fig_title, fontsize=20)

sns.lineplot(data=df_avg, x='Offer Type', y='Avg Chance', hue='Cluster')
sns.scatterplot(data=df_avg, x='Offer Type', y='Avg Chance', hue='Cluster', s=500)
plt.legend(cluster)

if(export_figure==True):
    plt.savefig(fig_dir+fig_title+'.png')
plt.show()

# %% [markdown]
# The chart series above gives us an idea of the characteristics of each cluster.
#
# ### Age and Gender
# * Customers with an older age (50-70) are mostly in cluster 0, while in clusters 1 and 2 are dominated by younger customers.
# * Although not significantly different, in each cluster it shows that the average age of women is older than men.
#
# ### Seniority
# * In terms of seniority, cluster 0 and cluster 2 share a similar distribution where customers who became members in 2015-2016 are mostly spread across these two clusters. Meanwhile, customers who recently joined (in 2018) dominate in cluster 1.
#
# ### Income
# * The distribution of income can be seen from the scatter plot of the comparison of income and amount.
# * Since most of the older customers are in cluster 0, we can also observe that the large income distribution (> 80,000) is in cluster 0.
# * For customers with income less than 80,000, they are divided into clusters 1 and 2 which are distinguished by the amount of transactions made.
#
# ### Amount of Transaction
# * We use sum and average to aggregate the amount of transactions.
#
# * Cluster 1 and cluster 2 are well distinguished from the total amount where cluster 1 has a smaller total amount than cluster 2.
#
# * Although cluster 0 dominates the entire range of total amount with income > 80,000, customers with this cluster also have a smaller income but have a large total amount (> 400).
#
# * From the point of view of an average transaction, cluster 1 is in the upper right corner which indicates a customer with a high value in terms of income and average amount.
#
# * For cluster 1 and cluster 2, there is overlap in the average amount, but in general cluster 1 (as before) has a smaller value than cluster 2.
#
# ### Possibility of Completing Offers
# * On the violin plot, it can be clearly seen that cluster 1 has a small probability of completion from both the BOGO and Discount offers.
#
# * Meanwhile, in Informational offers, the three clusters do not show a significant difference (keep in mind that specifically for informational offers, what is calculated is the number of views, different from other types of offers).
#
# * To be more specific in comparing cluster 0 and cluster 2, we will use a point plot that shows cluster 2 has a slightly higher average completion value.

# %% [markdown]
# ## 5. Conclusion and Recomendations

# %% [markdown]
# The results of the cluster analysis obtained from the K-Means method above provide some insight to us. The offers that have been given previously, BOGO and Discount, should be focused on customer cluster 0 and and cluster 2 which gives a greater possibility to complete the offer compared to cluster 1.<br>
#
# When compared between cluster 0 and cluster 1, cluster 0 which is dominated by customers with an older age and high income provides the biggest profit (in terms of total amount and average amount per transaction). However, cluster 0 still has a slightly lower probability of completing the offer. This needs to be a concern for the next offer period. <br>
#
# We recommend continuing to investigate some variables that have not been discussed in this project. Among them is the role of channel giving offers. Is there any influence between offers via web, email, mobile, or social channels? In addition, we have not paid attention to the reward points and dificulty of each offer given. Some of these things are potentials that can be explored further in the next project.

# %% [markdown]
# ## 6. Dig Deeper

# %% [markdown]
# In addition to Python notebooks, we have also created a dashboard using Tableau Public which can be accessed at the following link:
#
# https://public.tableau.com/app/profile/iqbal5898/viz/Starbucks_Clustering/StarbucksCustomerClustering

# %% [markdown]
# ![image.png](attachment:image.png)
